# %% [markdown]
# <a href="https://colab.research.google.com/github/Dielvic/Data-science-project/blob/main/Probleme_remont%C3%A9_de_donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import des librairies

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Import des bases de données

# %%
# Bases de donées Principales
data_account = pd.read_excel("OCPR_Account_Salesforce20210919.xlsx")
data_contact = pd.read_excel("OCPR_Contact_Salesforce20210919.xlsx")

# %%
#Base de donnée traitée (ante-traitemen et post-traitement)
data_received_file = pd.read_excel("OK FULL DEMAT.xlsx")
data_final = pd.read_excel("Ciblage-OK-Full-Demat-Test-_DK20210919.xlsx")

# %%
data_received_file = data_received_file.rename(columns= {"Code CIP pharmacie": "CIP"})

# %% [markdown]
# ## Breve analyse

# %%
data_received_file.head()
# Out:
#    Code CIP pharmacie  ... COMPLEMENT
# 0             2004464  ...        NaN
# 1             2153185  ...        NaN
# 2             2255226  ...        NaN
# 3             2002239  ...        NaN
# 4             2163303  ...        NaN
#
# [5 rows x 41 columns]

# %%
data_received_file.describe()
# Out:
#        Code CIP pharmacie  ...  COMPLEMENT
# count        8.250000e+02  ...         0.0
# mean         2.140791e+06  ...         NaN
# std          9.275689e+04  ...         NaN
# min          1.391001e+06  ...         NaN
# 25%          2.060138e+06  ...         NaN
# 50%          2.150472e+06  ...         NaN
# 75%          2.207586e+06  ...         NaN
# max          2.761422e+06  ...         NaN
#
# [8 rows x 16 columns]

# %%
data_received_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 41 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Code CIP pharmacie                      825 non-null    int64
#  1   Zone commerciale DVOC                   825 non-null    object
#  2   Nom du DVOC                             825 non-null    object
#  3   Zone commerciale REC                    825 non-null    object
#  4   Libellé DC                              825 non-null    object
#  5   Code du commercial                      825 non-null    int64
#  6   Nom du commercial                       825 non-null    object
#  7   Code CIP pharmacie.1                    825 non-null    int64
#  8   Numéro de client OCP                    825 non-null    int64
#  9   Identifiant BP                          825 non-null    int64
# ...

# %%
plt.figure(figsize=(14,14))
plt.subplot(2,2,1)
data_received_file['Segmentation marketing'].value_counts().plot.pie(autopct="%.1f%%")
plt.subplot(2,2,2)
data_received_file['Segmentation marketing (mois en cours)'].value_counts().plot.pie(autopct="%.1f%%")
plt.subplot(2,2,3)
data_received_file['Segment de client (mois en cours)'].value_counts().plot.pie(autopct="%.1f%%")
plt.subplot(2,2,4)
data_received_file['CLIENT PHASE TRANSITION ICMD '].value_counts().plot.pie(autopct="%.1f%%")
plt.legend()

# %%
data_received_file.head()
# Out:
#    Code CIP pharmacie  ... COMPLEMENT
# 0             2004464  ...        NaN
# 1             2153185  ...        NaN
# 2             2255226  ...        NaN
# 3             2002239  ...        NaN
# 4             2163303  ...        NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Affichage des données non remontées

# %%
t_2 = pd.merge(data_received_file, data_final,how='inner', on = 'CIP')

# %%
t_1 = pd.merge(data_received_file, data_final,how='outer', on = 'CIP')

# %%
t_1 - t_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ...
